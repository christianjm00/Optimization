# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
E=200*10**9 #Pa= N/m^2
rho=7800 #kg/m^3
c=0.1 #Ns/m
k=0.01#N/m
x_i=[0,10] #m
t=[0,600] #s
# Out:
# Eq(0.01*E*(1 - x_i)**2*(6*y_i - 4*y_{i+1} + y_{i+2} - 4*y_{i-1} + y_{i-2})/Δx**4 + 0.01*\rho*(1 - x_i)**2*(-2*y_i^j + y_i^{j+1} + y_i^{j-1})/Δt**2 + c*(y_i^{j+1} - y_i^{j-1})/(2*Δt) + k*y_i^j, 0)
