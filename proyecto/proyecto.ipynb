# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def Adaptive_Forward_Difference_21(f,t,epsilon,rl,ru,inter):
    # algoritmo 2.1
    h=2*np.sqrt(epsilon)/np.sqrt(3)
    l=0
    u=np.infty
    i=0
    while True:
        r=np.abs(f(t+4*h)-4*f(t+h)+3*f(t))/(8*epsilon)
        if r<rl:
            l=h
        elif r>ru:
            u=h
        else:
            break
        if u==np.infty:
            h*=4
        elif l==0:
            h/=4
        else:
            h=(l+u)/2
        if i>inter:
            break
        i+=1
    return h

# %%
def r_s(f,t,s,w,h,d,epsilon):
    res=np.sum(w*f(t+h*s))/(epsilon*h**d)
    return res
def Adaptive_Forward_Difference_31(f,t,s,w,h0,eta,epsilon,d,rl,ru,rs,intera):
    # algoritmo 3.1
    h=np.copy(h0)
    l=0
    u=np.infty
    inter=0
    while True:
        r=rs(f,t,s,w,h,d,epsilon)
        if r<rl:
            l=h
        elif r>ru:
            u=h
        else:
            break
        if u==np.infty:
            h*=eta
        elif l==0:
            h/=eta
        else:
            h=(l+u)/2
        if inter>intera:
            break
        inter+=1
    return h

# %%
def first_order_central_diff(f,t,h):
    # primera derivada central
    v_d_f=[]
    for i in range(len(t)):
        ei=np.zeros_like(t)
        ei[i]=1
        fs_r=(f(t+h*ei)-f(t-h*ei))/(2*h) 
        v_d_f.append(fs_r)   

    return np.array(v_d_f)

def second_order_central_diff(f,t,h):
    # segunda derivada central
    v_d_f=[]
    for i in range(len(t)):
        ei=np.zeros_like(t)
        ei[i]=1
        fs_r=(f(t+h*ei)-2*f(t)-f(t-h*ei))/(h**2)    
        v_d_f.append(fs_r)   

    return np.array(v_d_f)

def diff_d_th(f,t,s,w,h,d):
    # derivada d-th orden
    v_d_f=[]
    for i in range(len(t)):
        ei=np.zeros_like(t)
        ei[i]=1
        suma=0
        for sj,wj in zip(s,w):
            suma+=wj*f(t+h*sj*ei)
        v_d_f.append(suma/h**d)
    return np.array(v_d_f)

# %%
def backtracking(fun,x,fun_xk,p,grad_xk,alpha,c_1,rho,inter_b):
    alpha_i=np.copy(alpha)
    for i in range(inter_b):
        fun_alphai=fun(x+alpha_i*p)
        cond=fun_alphai<=fun_xk+c_1*alpha_i*np.dot(grad_xk,p)
        if cond:
            return  alpha_i, i
        alpha_i*=rho
    return  max(alpha_i,1e-8), i

def L_BFGS_two_loop_recursion(g,k,m,s,y,H):
    q=np.copy(g)
    inter=np.arange(np.max([0,k-m]),k)
    v_rho=[]
    v_alpha=[]
    for i in inter[::-1]:
        denom=np.dot(y[i],s[i])
        if np.abs(denom)<1e-10:
            denom=np.sign(denom)*1e-10  # evita dividir entre cero o muy pequeño
        rho=1.0/denom
        alpha=rho*np.dot(s[i],q)
        q-=alpha*y[i]
        v_alpha.append(alpha)
        v_rho.append(rho)
    v_alpha=np.array(v_alpha)
    v_rho=np.array(v_rho)
    r=np.dot(H,q)
    j=0
    for i in inter:
        beta=v_rho[j]*np.dot(y[i],r)
        r+=(v_alpha[j]-beta)*s[i]  
        j+=1      
    return r

def L_BFGS(f,g,H,tao,N,x,alpha,c_1,inter_b,rho_back,m,guardar=False):
    v_x=[]
    v_g=[]
    v_f=[]
    
    
    x_i=x
    f_i=f(x)
    g_i=g(x_i)
    H_0=np.copy(H)
    dim=H.shape
    I=np.eye(dim[0])
    res=0
    alpha_g=np.copy(alpha)
    v_s=[]
    v_y=[]
    for i in range(N):
        alpha=np.copy(alpha_g)
        n_g_i=np.linalg.norm(g_i)
        if guardar:
            v_x.append(np.copy(x_i))
            v_g.append(np.copy(g_i))
            v_f.append(np.copy(f_i))
        if n_g_i<tao:
            res=1
            break
        if i == 0:
            p_i=-np.dot(H_0, g_i)
        else:
            Hkgk=L_BFGS_two_loop_recursion(g_i, i, m, v_s, v_y, H_0)
            p_i=-Hkgk
  
        alpha,j=backtracking(f,x_i,f_i,p_i,g_i,alpha,c_1,rho_back,inter_b)
        x_ip1=x_i+alpha*p_i
        s_i=x_ip1-x_i
        g_ip1=g(x_ip1)
        y_i=g_ip1-g_i
        x_i=x_ip1
        g_i=g_ip1
        f_i=f(x_i)
        v_s.append(s_i)
        v_y.append(y_i)
        H_0=np.dot(s_i,y_i)/np.dot(y_i,y_i)*I
    if guardar:
        return  x_i,g_i,f_i,i,np.array(v_x),np.array(v_g),np.array(v_f),res
    else:
        return x_i,g_i,f_i,i,res

# %%
import numpy as np

# Función cuadrática: f(x) = x^T A x - b^T x
A = np.array([[2, 1], [1, 3]])
b = np.array([1, 2])
f = lambda x: x.T @ A @ x - b.T @ x
g = lambda x: 2 * A @ x - b

# Parámetros
x0 = np.array([0, 0])
alpha = 1.0
c_1 = 1e-4
rho_back = 0.5
inter_b = 100
m = 5
tao = 1e-6
N = 1000
H0 = np.eye(2)  # Hessiano inicial

# Ejecutar L-BFGS
x_opt, g_opt, f_opt, iter, res = L_BFGS(f, g, H0, tao, N, x0, alpha, c_1, inter_b, rho_back, m)
print(f"Solución: x = {x_opt}, f(x) = {f_opt}, iteraciones = {iter}")
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_29900\3799664440.py:77: RuntimeWarning: invalid value encountered in scalar divide
#   H_0=np.dot(s_i,y_i)/np.dot(y_i,y_i)*I
# C:\Users\chris\AppData\Local\Temp\ipykernel_29900\3799664440.py:20: RuntimeWarning: divide by zero encountered in scalar divide
#   rho=1.0/denom
# C:\Users\chris\AppData\Local\Temp\ipykernel_29900\3799664440.py:21: RuntimeWarning: invalid value encountered in scalar multiply
#   alpha=rho*np.dot(s[i],q)
# Solución: x = [nan nan], f(x) = nan, iteraciones = 999

# %%
def backtracking(fun,x,fun_xk,p,grad_xk,alpha,c_1,rho,inter_b):
    alpha_i=np.copy(alpha)
    for i in range(inter_b):
        fun_alphai=fun(x+alpha_i*p)
        cond=fun_alphai<=fun_xk+c_1*alpha_i*np.dot(grad_xk,p)
        if cond:
            return  alpha_i, i
        alpha_i*=rho
    return  max(alpha_i,1e-8), i

def BFGS_mod( f,g,H,tao,N,x,alpha,c_1,inter_b,rho_back,lambda_1=10**(-5),lambda_2=10**(-5),guardar=False):
    v_x=[]
    v_g=[]
    v_f=[]
    x_i=x
    f_i=f(x)
    g_i=g(x_i)
    H_i=np.copy(H)
    dim=H.shape
    I=np.eye(dim[0])
    res=0
    alpha_g=np.copy(alpha)
    for i in range(N):
        alpha=np.copy(alpha_g)
        n_g_i=np.linalg.norm(g_i)
        if guardar:
            v_x.append(np.copy(x_i))
            v_g.append(np.copy(g_i))
            v_f.append(np.copy(f_i))
        if n_g_i<tao:
            res=1
            break
        p_i=-np.dot(H_i,g_i)
        pg=np.dot(p_i,g_i)
        if pg>0:
            gg=np.dot(g_i,g_i)
            lambda_1=10**(-5)+pg/gg
            H_i+=lambda_1*I
            p_i-=lambda_1*g_i
        alpha,j=backtracking(f,x_i,f_i,p_i,g_i,alpha,c_1,rho_back,inter_b)
        x_ip1=x_i+alpha*p_i
        s_i=x_ip1-x_i
        g_ip1=g(x_ip1)
        y_i=g_ip1-g_i
        ys=np.dot(y_i,s_i)
        if ys<=0: 
            lambda_2=10**(-5)-ys/np.dot(y_i,y_i)
            H_i+=lambda_2*I
        else:
            rho=1/ys
            sy=np.outer(s_i,y_i)
            sy_o=np.outer(y_i,s_i)
            H_i=np.dot(I-rho*sy,np.dot(H_i,(I-rho*sy_o)))+rho*np.outer(s_i,s_i)
        x_i=x_ip1
        g_i=g_ip1
        f_i=f(x_i)

    if guardar:
        return  x_i,g_i,f_i,i,np.array(v_x),np.array(v_g),np.array(v_f),res
    else:
        return x_i,g_i,f_i,i,res

# %%
def fun_beale(x):
    return (1.5-x[0]+x[0]*x[1])**2+(2.25-x[0]+x[0]*x[1]**2)**2+(2.625-x[0]+x[0]*x[1]**3)**2

def grad_fun_beale(x):
    df_dx=2*(1.5-x[0]+x[0]*x[1])*(-1+x[1])+2*(2.25-x[0]+x[0]*x[1]**2)*(-1+x[1]**2)+2*(2.625-x[0]+x[0]*x[1]**3)*(-1+x[1]**3)

    df_dy=2*(1.5-x[0]+x[0]*x[1])*x[0]+2*(2.25-x[0]+x[0]*x[1]**2)*(2*x[1]*x[0])+2*(2.625-x[0]+x[0]*x[1]**3)*(3*x[0]*x[1]**2)
    return np.array([df_dx,df_dy])

def Hess_fun_beale(x):
    d2f_d2x=2*(-1+x[1])**2+2*(-1+x[1]**2)**2+2*(-1+x[1]**3)**2
    d2f_dxdy=2*x[0]*(-1+x[1])+2*(1.5-x[0]+x[0]*x[1])+4*x[0]*x[1]*(-1+x[1]**2)+4*x[1]*(2.25-x[0]+x[0]*x[1]**2)+6*x[0]*(x[1]**2)*(-1+x[1]**3)+6*(x[1]**2)*(2.625-x[0]+x[0]*x[1]**3)
    d2f_d2y=2*x[0]**2+8*(x[0]**2)*(x[1]**2)+18*(x[0]**2)*(x[1]**4)
    return np.array([[d2f_d2x,d2f_dxdy],[d2f_dxdy,d2f_d2y]])

# %%
import time as tm
def prueba(nom_fu,func,grad,Hess,x_ini,guardar):
    print("resultado "+nom_fu)
    
    tm_0=tm.time()
    x_k,g_k,f_k,i,v_x,v_g,v_f,res=L_BFGS(f=func,g=grad,H=Hess,tao=10**(-3),N=10000,x=np.copy(x_ini),
                                     alpha=1.0,c_1=0.1,inter_b=100,rho_back=0.6,m=10,guardar=guardar)
    tm_1=tm.time()
    print("time:",tm_1-tm_0)
    print("f(x_ini):",func(x_ini))
    print("iterracciones:",i)
    print("res:",res)
    print("norma de g_k",np.linalg.norm(g_k))
    po=10
    if len(v_x)<=po:
        print(v_x)
    else:
        print(v_x[:int(po/2)])
        print(v_x[-int(po/2):])
    print("f(x_k):",f_k)

    if len(x_ini)==2:
        x_0=np.linspace(-5,5,400)
        x_1=np.linspace(-5,5,400)
        x_0,x_1=np.meshgrid(x_0,x_1)
        fu_g=func(np.array([x_0,x_1]))
        plt.figure()
        contours=plt.contour(x_0, x_1, fu_g, levels=7, colors='black')  # Líneas de contorno
        plt.clabel(contours, inline=True, fontsize=8)
        plt.plot(v_x[:,0],v_x[:,1],label="x")
        plt.xlabel(r"$x_1$")
        plt.ylabel(r"$x_2$")
        plt.title("Gráfica de "+nom_fu)
        plt.legend()
        plt.savefig("pro_4_1_"+nom_fu+".pdf")

        fig = plt.figure(figsize=(10, 8))
        ax = fig.add_subplot(111, projection='3d')
        surf = ax.plot_surface(x_0, x_1, fu_g, cmap='viridis')
        fig.colorbar(surf, shrink=0.5, aspect=5)
        ax.plot(v_x[:,0],v_x[:,1],v_f,linewidth=5,label="punto evaluacion")
        # Etiquetas
        ax.set_xlabel(r'$x_0$')
        ax.set_ylabel(r'$x_1$')
        ax.set_zlabel(r'f')
        ax.set_title('Gráfica de '+nom_fu)
        plt.savefig("pro_4_2_"+nom_fu+".pdf")
        plt.show()

    plt.figure()
    plt.scatter(np.arange(len(v_g)),np.linalg.norm(v_g,axis=1),label="error")
    plt.xlabel("iteracciones")
    plt.ylabel(r"$\|\nabla f(x_k)\|$")
    plt.title(r"Gráfica $\|\nabla f(x_k)\|$ de "+nom_fu)
    plt.legend()
    plt.savefig("pro_4_3_"+nom_fu+".pdf")

# %%
x_0_beale=np.array([2,0.5])
hess_be=np.eye(2)
print(hess_be)
inv_Hess_be=np.linalg.inv(hess_be)
prueba("beale",fun_beale,grad_fun_beale,inv_Hess_be,x_0_beale,True)
# Out:
# [[1. 0.]
#  [0. 1.]]
# resultado beale
# C:\Users\chris\AppData\Local\Temp\ipykernel_29900\1232095892.py:2: RuntimeWarning: overflow encountered in scalar multiply
#   return (1.5-x[0]+x[0]*x[1])**2+(2.25-x[0]+x[0]*x[1]**2)**2+(2.625-x[0]+x[0]*x[1]**3)**2
# C:\Users\chris\AppData\Local\Temp\ipykernel_29900\1232095892.py:2: RuntimeWarning: overflow encountered in scalar power
#   return (1.5-x[0]+x[0]*x[1])**2+(2.25-x[0]+x[0]*x[1]**2)**2+(2.625-x[0]+x[0]*x[1]**3)**2
# C:\Users\chris\AppData\Local\Temp\ipykernel_29900\1232095892.py:5: RuntimeWarning: overflow encountered in scalar multiply
#   df_dx=2*(1.5-x[0]+x[0]*x[1])*(-1+x[1])+2*(2.25-x[0]+x[0]*x[1]**2)*(-1+x[1]**2)+2*(2.625-x[0]+x[0]*x[1]**3)*(-1+x[1]**3)
# C:\Users\chris\AppData\Local\Temp\ipykernel_29900\1232095892.py:5: RuntimeWarning: overflow encountered in scalar power
#   df_dx=2*(1.5-x[0]+x[0]*x[1])*(-1+x[1])+2*(2.25-x[0]+x[0]*x[1]**2)*(-1+x[1]**2)+2*(2.625-x[0]+x[0]*x[1]**3)*(-1+x[1]**3)
# C:\Users\chris\AppData\Local\Temp\ipykernel_29900\1232095892.py:7: RuntimeWarning: overflow encountered in scalar multiply
#   df_dy=2*(1.5-x[0]+x[0]*x[1])*x[0]+2*(2.25-x[0]+x[0]*x[1]**2)*(2*x[1]*x[0])+2*(2.625-x[0]+x[0]*x[1]**3)*(3*x[0]*x[1]**2)
# C:\Users\chris\AppData\Local\Temp\ipykernel_29900\1232095892.py:7: RuntimeWarning: overflow encountered in scalar power
#   df_dy=2*(1.5-x[0]+x[0]*x[1])*x[0]+2*(2.25-x[0]+x[0]*x[1]**2)*(2*x[1]*x[0])+2*(2.625-x[0]+x[0]*x[1]**3)*(3*x[0]*x[1]**2)
# C:\Users\chris\AppData\Local\Temp\ipykernel_29900\3799664440.py:77: RuntimeWarning: invalid value encountered in scalar divide
#   H_0=np.dot(s_i,y_i)/np.dot(y_i,y_i)*I
# C:\Users\chris\AppData\Local\Temp\ipykernel_29900\3799664440.py:21: RuntimeWarning: invalid value encountered in scalar multiply
#   alpha=rho*np.dot(s[i],q)
# time: 9.046875953674316
# f(x_ini): 1.578125
# iterracciones: 9999
# res: 0
# norma de g_k nan
# [[2.         0.5       ]
#  [2.147258   0.144248  ]
#  [2.17371241 0.18653081]
#  [2.17371241 0.18653081]
#  [2.71975852 0.32046433]]
# [[nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]]
# f(x_k): nan
# c:\Users\chris\AppData\Local\Programs\Python\Python310\lib\site-packages\mpl_toolkits\mplot3d\proj3d.py:113: RuntimeWarning: invalid value encountered in divide
#   txs, tys, tzs = vecw[0]/w, vecw[1]/w, vecw[2]/w
# c:\Users\chris\AppData\Local\Programs\Python\Python310\lib\site-packages\mpl_toolkits\mplot3d\proj3d.py:113: RuntimeWarning: invalid value encountered in divide
#   txs, tys, tzs = vecw[0]/w, vecw[1]/w, vecw[2]/w
# c:\Users\chris\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\linalg\linalg.py:2582: RuntimeWarning: overflow encountered in multiply
#   s = (x.conj() * x).real

# %%
from sympy import symbols, Eq,expand,collect,latex

# Parámetros
E, rho, c, k = symbols(r'E \rho c k')
Δx, Δt, x_i = symbols('Δx Δt x_i')

# Variables discretas
y_i2 = symbols('y_{i-2}')
y_i1 = symbols('y_{i-1}')
y_i = symbols('y_i')
y_i1p = symbols('y_{i+1}')
y_i2p = symbols('y_{i+2}')

yijm1 = symbols('y_i^{j-1}')
yij = symbols('y_i^j')
yijp1 = symbols('y_i^{j+1}')

# Coeficiente
coef = (-0.1 * x_i + 0.1)**2

# Términos
term1 = coef * E * (y_i2 - 4*y_i1 + 6*y_i - 4*y_i1p + y_i2p) / Δx**4
term2 = rho * coef * (yijp1 - 2*yij + yijm1) / Δt**2
term3 = c * (yijp1 - yijm1) / (2*Δt)
term4 = k * yij

# Ecuación
eq = Eq(term1 + term2 + term3 + term4, 0)

# Mostrar la ecuación
eq
eq_1=expand(eq.lhs)
eq_2=collect(eq_1, [y_i2,y_i1,y_i,y_i1p,y_i2p,yijm1,yij,yijp1])
display(eq_2)
latex_code=latex(eq_2)
print(latex_code)
# Out:
# y_i*(0.06*E*x_i**2/Δx**4 - 0.12*E*x_i/Δx**4 + 0.06*E/Δx**4) + y_i^j*(-0.02*\rho*x_i**2/Δt**2 + 0.04*\rho*x_i/Δt**2 - 0.02*\rho/Δt**2 + k) + y_i^{j+1}*(0.01*\rho*x_i**2/Δt**2 - 0.02*\rho*x_i/Δt**2 + 0.01*\rho/Δt**2 + c/(2*Δt)) + y_i^{j-1}*(0.01*\rho*x_i**2/Δt**2 - 0.02*\rho*x_i/Δt**2 + 0.01*\rho/Δt**2 - c/(2*Δt)) + y_{i+1}*(-0.04*E*x_i**2/Δx**4 + 0.08*E*x_i/Δx**4 - 0.04*E/Δx**4) + y_{i+2}*(0.01*E*x_i**2/Δx**4 - 0.02*E*x_i/Δx**4 + 0.01*E/Δx**4) + y_{i-1}*(-0.04*E*x_i**2/Δx**4 + 0.08*E*x_i/Δx**4 - 0.04*E/Δx**4) + y_{i-2}*(0.01*E*x_i**2/Δx**4 - 0.02*E*x_i/Δx**4 + 0.01*E/Δx**4)
# y_{i} \left(\frac{0.06 E x_{i}^{2}}{Δx^{4}} - \frac{0.12 E x_{i}}{Δx^{4}} + \frac{0.06 E}{Δx^{4}}\right) + y^{j}_{i} \left(- \frac{0.02 \rho x_{i}^{2}}{Δt^{2}} + \frac{0.04 \rho x_{i}}{Δt^{2}} - \frac{0.02 \rho}{Δt^{2}} + k\right) + y_i^{j+1} \left(\frac{0.01 \rho x_{i}^{2}}{Δt^{2}} - \frac{0.02 \rho x_{i}}{Δt^{2}} + \frac{0.01 \rho}{Δt^{2}} + \frac{c}{2 Δt}\right) + y_i^{j-1} \left(\frac{0.01 \rho x_{i}^{2}}{Δt^{2}} - \frac{0.02 \rho x_{i}}{Δt^{2}} + \frac{0.01 \rho}{Δt^{2}} - \frac{c}{2 Δt}\right) + y_{i+1} \left(- \frac{0.04 E x_{i}^{2}}{Δx^{4}} + \frac{0.08 E x_{i}}{Δx^{4}} - \frac{0.04 E}{Δx^{4}}\right) + y_{i+2} \left(\frac{0.01 E x_{i}^{2}}{Δx^{4}} - \frac{0.02 E x_{i}}{Δx^{4}} + \frac{0.01 E}{Δx^{4}}\right) + y_{i-1} \left(- \frac{0.04 E x_{i}^{2}}{Δx^{4}} + \frac{0.08 E x_{i}}{Δx^{4}} - \frac{0.04 E}{Δx^{4}}\right) + y_{i-2} \left(\frac{0.01 E x_{i}^{2}}{Δx^{4}} - \frac{0.02 E x_{i}}{Δx^{4}} + \frac{0.01 E}{Δx^{4}}\right)

# %%
E=200*10**9 #Pa= N/m^2
rho=7800 #kg/m^3
c=0.1 #Ns/m
k=0.01#N/m
x=[0,1] #m
t=[0,600] #s

# %%
def c_0(x_i,dx,dt):
    rc_0=(0.06*E*x_i**2)/(dx**4)-(0.12*E*x_i)/(dx**4)+(0.06*E)/(dx**4)
    return rc_0
def c_1(x_i,dx,dt):
    rc_1=-(0.02*rho*x_i**2)/(dt**2)+(0.04*rho*x_i)/(dt**2)-(0.02*rho)/(dt**2)+k
    return rc_1
def c_2(x_i,dx,dt):
    rc_2=-(0.01*rho*x_i**2)/(dt**2)-(0.02*rho*x_i)/(dt**2)+(0.01*rho)/(dt**2)+c/(2*dt)
    return rc_2
def c_3(x_i,dx,dt):
    rc_3=(0.01*rho*x_i**2)/(dt**2)-(0.02*rho*x_i)/(dt**2)+(0.01*rho)/(dt**2)-c/(2*dt)
    return rc_3
def c_4(x_i,dx,dt):
    rc_4=-(0.04*E*x_i**2)/(dx**4)+(0.08*E*x_i)/(dx**4)-(0.04*E)/(dx**4)
    return rc_4
def c_5(x_i,dx,dt):
    rc_5=(0.01*E*x_i**2)/(dx**4)-(0.02*E*x_i)/(dx**4)+(0.01*E)/(dx**4)
    return rc_5
def c_6(x_i,dx,dt):
    rc_6=-(0.04*E*x_i**2)/(dx**4)+(0.08*E*x_i)/(dx**4)-(0.04*E)/(dx**4)
    return rc_6
def c_7(x_i,dx,dt):
    rc_7=(0.01*E*x_i**2)/(dx**4)-(0.02*E*x_i)/(dx**4)+(0.01*E)/(dx**4)
    return rc_7

# %%
def f_A(x,dx,dt,dim):
    A=np.zeros((dim,dim))
    i=np.arange(dim)
    A[i,i]=c_0(x,dx,dt)+c_1(x,dx,dt)
    A[i[:-1],i[1:]]=c_4(x[1:],dx,dt)
    A[i[:-2],i[2:]]=c_5(x[2:],dx,dt)
    A[i[1:],i[:-1]]=c_6(x[:-1],dx,dt)
    A[i[2:],i[:-2]]=c_5(x[:-2],dx,dt)
    return A

# %%
def f_L(x,y_j,y_jp1,y_jl1,lambda_1,lambda_2,lambda_3,lambda_4,dx,dt,f_f,t):
    dim=len(x)
    eva_c2=c_2(x,dx,dt)
    eva_c3=c_3(x,dx,dt)
    
    ma_c2=np.diag(1/eva_c2)
    ma_c3c2=np.diag(eva_c3/eva_c2)
    f_1=np.dot(ma_c2,np.dot(f_A(x,dx,dt,dim),y_j))-y_jp1+np.dot(ma_c3c2,y_jl1)
    f_2=np.dot(f_1,f_1)
    f_3=lambda_1*(y_j[0])**2
    f_4=lambda_2*(y_j[2]-4*y_j[1])**2
    f_5=lambda_3*(y_j[-1]-2*y_j[-2]+y_j[-3])**2
    I_1=(-0.1*x[-1]+0.1)**4
    f_6=lambda_4*((E*I_1)*(-y_j[-4]+3*y_j[-3]-3*y_j[-2]+y_j[-1])/(dx**3)-f_f(t))**2
    L=f_2+f_3+f_4+f_5+f_6
    return L

# %%
def g_f_L(x,y_j,y_jl1,v,dx,dt,f_f,t,s,w,dy):
    def di_f_L(v):
        y_jp1=v[:-4]
        lambdas=v[-4:]
        
        return f_L(x,y_j,y_jp1,y_jl1,lambdas[0],lambdas[1],lambdas[2],lambdas[3],dx,dt,f_f,t)
    #g=diff_d_th(di_f_L,v,s,w,dy,1)
    g=first_order_central_diff(di_f_L,v,dy)
    return g

# %%
def fun_f(t):
    return 100*np.sin(10*t)

# %%
N=50
hess=np.eye(N+4)
v_x=np.linspace(x[0],x[1],N)
v_t=np.linspace(t[0],t[1],t[1])
v_y_so=[]
v_y_so.append(np.zeros_like(v_x))
for ti in v_t:
    if ti==0:
        y_j=np.zeros_like(v_x)
        y_jl1=np.zeros_like(v_x)
    def op_f(v):
        y_jp1=v[:-4]
        lambdas=v[-4:]
        return f_L(v_x,y_j,y_jp1,y_jl1,lambdas[0],lambdas[1],lambdas[2],lambdas[3],v_x[1],v_t[1],fun_f,ti)
    def gra_op_f(v):
        s=np.array([-1,1])
        w=np.array([-1/2,1/2])
        dy=Adaptive_Forward_Difference_21(op_f,v,0.01,1.5,6,100)
        return g_f_L(v_x,y_j,y_jl1,v,v_x[1],v_t[1],fun_f,ti,s,w,dy)
    v_ini=np.zeros(N+4)
    tm_0=tm.time()
    sol_k,g_k,f_k,i,v_sol_k,_,_,res=BFGS_mod(f=op_f,g=gra_op_f,H=hess,tao=10**(-6),N=10000,x=np.copy(v_ini),
                                     alpha=1.0,c_1=0.1,inter_b=100,rho_back=0.6,guardar=True)
    tm_1=tm.time()
    print("ti:",ti)
    print("time:",tm_1-tm_0)
    print("f(x_ini):",op_f(v_ini))
    print("iterracciones:",i)
    print("res:",res)
    print("norma de g_k",np.linalg.norm(g_k))
    po=6
    """
     if len(v_x)<=po:
        print(v_sol_k)
    else:
        print(v_sol_k[:int(po/2)])
        print(v_sol_k[-int(po/2):])
    """

    print("f(x_k):",f_k)
    y_jl1=np.copy(y_j)

    y_j=np.copy(v_sol_k[0][:-4])

    v_y_so.append(y_j)
# Out:
# ti: 0.0
# time: 0.01787567138671875
# f(x_ini): 0.0
# iterracciones: 0
# res: 1
# norma de g_k 0.0
# f(x_k): 0.0
# ti: 1.001669449081803
# time: 0.0816192626953125
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.4529121146846646e+18
# ti: 2.003338898163606
# time: 0.14002585411071777
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.7423872715404948e+20
# ti: 3.005008347245409
# time: 0.17036867141723633
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.5119382694492926e+21
# ti: 4.006677796327212
# time: 0.15198087692260742
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -7.504742425098196e+18
# ti: 5.0083472454090145
# time: 0.07586288452148438
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.7263159443321648e+17
# ti: 6.010016694490818
# time: 0.14374732971191406
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -7.666376930168784e+18
# ti: 7.011686143572621
# time: 0.08620119094848633
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.2679938016043804e+20
# ti: 8.013355592654424
# time: 0.07998991012573242
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0932069147882818e+19
# ti: 9.015025041736227
# time: 0.2432880401611328
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -7.913663125702522e+22
# ti: 10.016694490818029
# time: 0.1269378662109375
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -7.494384494405352e+18
# ti: 11.018363939899833
# time: 0.19170546531677246
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.082987860253437e+20
# ti: 12.020033388981636
# time: 0.12793684005737305
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.9130681849445708e+19
# ti: 13.021702838063439
# time: 0.18005871772766113
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -3.1128307892959975e+21
# ti: 14.023372287145243
# time: 0.13034701347351074
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.694726774714154e+19
# ti: 15.025041736227045
# time: 0.07957339286804199
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.4542357931337667e+18
# ti: 16.026711185308848
# time: 0.08040142059326172
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.1016891358920164e+16
# ti: 17.02838063439065
# time: 0.13465118408203125
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -6.532372319061717e+20
# ti: 18.030050083472453
# time: 0.19008350372314453
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -2.4571557050131962e+20
# ti: 19.031719532554256
# time: 0.0901486873626709
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.4208918206255557e+19
# ti: 20.033388981636058
# time: 0.13971924781799316
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.523588167685258e+20
# ti: 21.035058430717864
# time: 0.08521580696105957
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -3.812828125103669e+16
# ti: 22.036727879799667
# time: 0.12704014778137207
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.448786796021759e+18
# ti: 23.03839732888147
# time: 0.08786940574645996
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -9.994181246333565e+18
# ti: 24.040066777963272
# time: 0.08194112777709961
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.4938413047940045e+18
# ti: 25.041736227045075
# time: 0.1416616439819336
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0258996581216107e+20
# ti: 26.043405676126877
# time: 0.2167363166809082
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.1494567851071454e+20
# ti: 27.04507512520868
# time: 0.09173011779785156
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -3.287088472196116e+17
# ti: 28.046744574290486
# time: 0.09049105644226074
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -7.029820153243499e+19
# ti: 29.04841402337229
# time: 0.12736272811889648
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.8936546699138777e+20
# ti: 30.05008347245409
# time: 0.14036297798156738
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.8456789292129845e+19
# ti: 31.051752921535893
# time: 0.19501924514770508
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -6.219862466922957e+20
# ti: 32.053422370617696
# time: 0.13400912284851074
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.9155941734832366e+18
# ti: 33.0550918196995
# time: 0.19863200187683105
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.3315121068236984e+21
# ti: 34.0567612687813
# time: 0.18010544776916504
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -2.4227374244773815e+21
# ti: 35.058430717863104
# time: 0.13027644157409668
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -5.76290722281049e+19
# ti: 36.060100166944906
# time: 0.13796424865722656
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -9.3156834910594e+19
# ti: 37.06176961602671
# time: 0.08387231826782227
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.1908916038374675e+17
# ti: 38.06343906510851
# time: 0.17415213584899902
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.794468834993894e+21
# ti: 39.065108514190314
# time: 0.1391282081604004
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.4174971201059625e+20
# ti: 40.066777963272116
# time: 0.07485246658325195
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -8.757953916939614e+18
# ti: 41.068447412353926
# time: 0.0898735523223877
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -6.769572371303422e+18
# ti: 42.07011686143573
# time: 0.07486963272094727
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.1606707431641878e+17
# ti: 43.07178631051753
# time: 0.2081756591796875
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.104652936629532e+20
# ti: 44.073455759599334
# time: 0.1498429775238037
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0310397640694231e+19
# ti: 45.075125208681136
# time: 0.07700610160827637
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.286873862190104e+19
# C:\Users\chris\AppData\Local\Temp\ipykernel_29900\3793180239.py:47: RuntimeWarning: invalid value encountered in scalar divide
#   lambda_2=10**(-5)-ys/np.dot(y_i,y_i)
# ti: 46.07679465776294
# time: 385.7973873615265
# f(x_ini): 0.0
# iterracciones: 9999
# res: 0
# norma de g_k nan
# f(x_k): nan
# ti: 47.07846410684474
# time: 0.17253947257995605
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -8.10327794844779e+19
# ti: 48.080133555926544
# time: 0.15738677978515625
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.0735724157038083e+18
# ti: 49.08180300500835
# time: 0.08900189399719238
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -4.061906545551241e+19
# ti: 50.08347245409015
# time: 0.23503637313842773
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.5057332075774419e+21
# ti: 51.08514190317195
# time: 0.33351802825927734
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -5.189607020771598e+22
# ti: 52.086811352253754
# time: 0.224043607711792
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.6167731748048873e+20
# ti: 53.08848080133556
# time: 0.09023666381835938
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -3790479770134223.5
# ti: 54.09015025041736
# time: 0.08737492561340332
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.8354696451614456e+18
# ti: 55.09181969949916
# time: 0.188523530960083
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.0274947530231874e+20
# ti: 56.09348914858097
# time: 0.1839613914489746
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.1669179969840108e+21
# ti: 57.095158597662774
# time: 0.24558424949645996
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -8.622369336329196e+19
# ti: 58.09682804674458
# time: 0.16312217712402344
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.939972786956682e+19
# ti: 59.09849749582638
# time: 0.11927318572998047
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5.974432442382346e+17
# ti: 60.10016694490818
# time: 0.24084258079528809
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.6325402064717095e+21
# ti: 61.101836393989984
# time: 0.08300614356994629
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.939930988957003e+20
# ti: 62.10350584307179
# time: 0.1500406265258789
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -7.302185464560189e+19
# ti: 63.10517529215359
# time: 0.15859198570251465
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.636201776835266e+19
# ti: 64.10684474123539
# time: 0.12183499336242676
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.725507578988107e+17
# ti: 65.1085141903172
# time: 0.18305683135986328
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.045020497600995e+20
# ti: 66.110183639399
# time: 0.08974289894104004
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -6.440680834805915e+18
# ti: 67.1118530884808
# time: 0.1468501091003418
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.313575023756966e+19
# ti: 68.1135225375626
# time: 0.39812278747558594
# f(x_ini): 0.0
# iterracciones: 6
# res: 1
# norma de g_k 0.0
# f(x_k): -3.445720267529276e+21
# ti: 69.1151919866444
# time: 0.08189105987548828
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -19342192732829.918
# ti: 70.11686143572621
# time: 0.12492609024047852
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5.549046370111254e+18
# ti: 71.11853088480801
# time: 0.38515782356262207
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -1.7268710245839193e+23
# ti: 72.12020033388981
# time: 0.17267084121704102
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -8.117456479993722e+19
# ti: 73.12186978297161
# time: 0.09743332862854004
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -7.044441367641987e+18
# ti: 74.12353923205342
# time: 0.08339905738830566
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -8.652407744902015e+18
# ti: 75.12520868113522
# time: 0.15186047554016113
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.253432040103737e+19
# ti: 76.12687813021702
# time: 0.16797995567321777
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -6.622130856781251e+19
# ti: 77.12854757929883
# time: 0.0932929515838623
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -3.8148647866593985e+19
# ti: 78.13021702838063
# time: 0.1988062858581543
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -3.718296338090795e+21
# ti: 79.13188647746243
# time: 0.1439650058746338
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -5.906187776251676e+19
# ti: 80.13355592654423
# time: 0.14046883583068848
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -9.395580256292854e+18
# ti: 81.13522537562605
# time: 0.14969587326049805
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.901420859895296e+20
# ti: 82.13689482470785
# time: 0.35272955894470215
# f(x_ini): 0.0
# iterracciones: 6
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0246464570494292e+22
# ti: 83.13856427378965
# time: 0.19706058502197266
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.3068728886425392e+20
# ti: 84.14023372287146
# time: 0.12677597999572754
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.433684109119987e+18
# ti: 85.14190317195326
# time: 0.11507821083068848
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -4.3757465304787896e+16
# ti: 86.14357262103506
# time: 0.1751265525817871
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.6896155460662804e+19
# ti: 87.14524207011686
# time: 0.2153463363647461
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -5.478969821343612e+21
# ti: 88.14691151919867
# time: 0.09493732452392578
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.5672927121504805e+19
# ti: 89.14858096828047
# time: 0.11080360412597656
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0204739380472503e+18
# ti: 90.15025041736227
# time: 0.23523688316345215
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -3.685567414719097e+18
# ti: 91.15191986644408
# time: 0.14073514938354492
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.1951503313644025e+20
# ti: 92.15358931552588
# time: 0.08816409111022949
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.0159294124063465e+19
# ti: 93.15525876460768
# time: 0.08656573295593262
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5.199111247564346e+19
# ti: 94.15692821368948
# time: 0.20998883247375488
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -6.862135614090582e+20
# ti: 95.15859766277129
# time: 0.15333008766174316
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -5.665515265663925e+18
# ti: 96.16026711185309
# time: 0.09116601943969727
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.5312782233835123e+17
# ti: 97.16193656093489
# time: 0.09368753433227539
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -7.021798854322482e+18
# ti: 98.1636060100167
# time: 0.2598226070404053
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -1.9311902818920183e+21
# ti: 99.1652754590985
# time: 0.08246707916259766
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0690884984343593e+19
# ti: 100.1669449081803
# time: 0.14938092231750488
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.643288317158197e+18
# ti: 101.1686143572621
# time: 0.09037566184997559
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0962072178697216e+17
# ti: 102.1702838063439
# time: 0.2176976203918457
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.616318601452164e+20
# ti: 103.1719532554257
# time: 0.1401076316833496
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.1003629097712193e+21
# ti: 104.17362270450751
# time: 0.10048675537109375
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0244586392810377e+19
# ti: 105.17529215358931
# time: 0.14962053298950195
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.051076873510496e+21
# ti: 106.17696160267111
# time: 0.1472463607788086
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -5.19352743669313e+17
# ti: 107.17863105175292
# time: 0.21013498306274414
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -5.053619771257776e+20
# ti: 108.18030050083472
# time: 0.10686063766479492
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -9.215392450911433e+18
# ti: 109.18196994991652
# time: 0.17013859748840332
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -9.535376017286013e+20
# ti: 110.18363939899832
# time: 0.28977465629577637
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0191286730051555e+21
# ti: 111.18530884808013
# time: 0.14845967292785645
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.4826145650024095e+18
# ti: 112.18697829716194
# time: 0.20497822761535645
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.6926281789718276e+20
# ti: 113.18864774624375
# time: 0.16045546531677246
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.107145685306179e+20
# ti: 114.19031719532555
# time: 0.12142014503479004
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -9.698764135241683e+18
# ti: 115.19198664440735
# time: 0.09378409385681152
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -4.853716274847329e+18
# ti: 116.19365609348915
# time: 0.19396615028381348
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.574163747962846e+19
# ti: 117.19532554257096
# time: 0.17928504943847656
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -9.580367383008252e+17
# ti: 118.19699499165276
# time: 0.3456873893737793
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -2.6606609350214127e+20
# ti: 119.19866444073456
# time: 0.11766886711120605
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -6.989758391234466e+18
# ti: 120.20033388981636
# time: 0.22951388359069824
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -9.711801546955907e+19
# ti: 121.20200333889817
# time: 0.16528844833374023
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.188854686794211e+20
# ti: 122.20367278797997
# time: 0.18584871292114258
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -7395455631809038.0
# ti: 123.20534223706177
# time: 0.26908373832702637
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -6.671285008112857e+20
# ti: 124.20701168614357
# time: 0.1697094440460205
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -3.199838076374453e+19
# ti: 125.20868113522538
# time: 0.08230924606323242
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.7693947911707818e+19
# ti: 126.21035058430718
# time: 0.19297528266906738
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.2173462803273343e+21
# ti: 127.21202003338898
# time: 382.43978118896484
# f(x_ini): 0.0
# iterracciones: 9999
# res: 0
# norma de g_k nan
# f(x_k): nan
# ti: 128.21368948247078
# time: 0.10564303398132324
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.298815607062845e+18
# ti: 129.2153589315526
# time: 0.2103877067565918
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.6153741642828385e+20
# ti: 130.2170283806344
# time: 0.1611776351928711
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -5.868624794292443e+21
# ti: 131.2186978297162
# time: 0.09036517143249512
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.575951531375104e+18
# ti: 132.220367278798
# time: 0.13142919540405273
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.4264912520109594e+18
# ti: 133.2220367278798
# time: 0.2294902801513672
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.1418905085391832e+18
# ti: 134.2237061769616
# time: 0.12487316131591797
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.5435232378095075e+20
# ti: 135.22537562604342
# time: 0.13381361961364746
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.8963731469576266e+19
# ti: 136.2270450751252
# time: 0.08073592185974121
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -7.326963432122595e+18
# ti: 137.22871452420702
# time: 0.10541462898254395
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -9.370057920793421e+17
# ti: 138.2303839732888
# time: 0.04557204246520996
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -60580523798264.32
# ti: 139.23205342237063
# time: 0.12457919120788574
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.68337509523915e+20
# ti: 140.23372287145241
# time: 0.0919194221496582
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.369860547728813e+19
# ti: 141.23539232053423
# time: 0.09961724281311035
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -6.66776347607075e+18
# ti: 142.23706176961602
# time: 0.33624696731567383
# f(x_ini): 0.0
# iterracciones: 6
# res: 1
# norma de g_k 0.0
# f(x_k): -1.2180837081429162e+21
# ti: 143.23873121869784
# time: 0.14190030097961426
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -5.950057698377713e+18
# ti: 144.24040066777962
# time: 0.11161327362060547
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.3841963815994353e+18
# ti: 145.24207011686144
# time: 0.19972920417785645
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.66770715258757e+20
# ti: 146.24373956594323
# time: 0.08866214752197266
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.3376250258904883e+19
# ti: 147.24540901502505
# time: 0.1902306079864502
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.895773194545223e+19
# ti: 148.24707846410683
# time: 0.10841202735900879
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -8.210253299676739e+17
# ti: 149.24874791318865
# time: 0.20139455795288086
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -3.75970797967084e+19
# ti: 150.25041736227044
# time: 0.1501624584197998
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0736998640592611e+20
# ti: 151.25208681135226
# time: 0.10121393203735352
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.5633405197436836e+20
# ti: 152.25375626043405
# time: 0.1487743854522705
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -3.075377044950256e+19
# ti: 153.25542570951586
# time: 0.119659423828125
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.6250646027773233e+18
# ti: 154.25709515859765
# time: 0.3102257251739502
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.504100751224181e+16
# ti: 155.25876460767947
# time: 0.1269986629486084
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.1857945734876969e+19
# ti: 156.26043405676126
# time: 0.13075995445251465
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.2436434205695895e+21
# ti: 157.26210350584307
# time: 0.21728873252868652
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -3.131059145158313e+21
# ti: 158.26377295492486
# time: 0.07658267021179199
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.559091476846248e+18
# ti: 159.26544240400668
# time: 0.12474584579467773
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.942499651538116e+18
# ti: 160.26711185308847
# time: 0.14463090896606445
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.0686745964418744e+19
# ti: 161.26878130217028
# time: 0.18769049644470215
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.320255010210806e+23
# ti: 162.2704507512521
# time: 0.08250188827514648
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.966724709510785e+18
# ti: 163.2721202003339
# time: 0.15245270729064941
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.648817826193029e+21
# ti: 164.2737896494157
# time: 0.13532471656799316
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -8.298242960146811e+21
# ti: 165.2754590984975
# time: 0.224196195602417
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.979411052979503e+18
# ti: 166.2771285475793
# time: 0.09557819366455078
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -7.330427182080109e+18
# ti: 167.2787979966611
# time: 0.09627127647399902
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -9.180315929285492e+18
# ti: 168.28046744574291
# time: 0.19381237030029297
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.698685620030659e+20
# ti: 169.2821368948247
# time: 0.16192078590393066
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -7.233884353734046e+18
# ti: 170.28380634390652
# time: 0.11920547485351562
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.398483085144715e+17
# ti: 171.2854757929883
# time: 0.07896280288696289
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -3.67725465126168e+19
# ti: 172.28714524207012
# time: 0.1428213119506836
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -9.480095557836648e+18
# ti: 173.2888146911519
# time: 0.1369318962097168
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.945213115076064e+20
# ti: 174.29048414023373
# time: 0.3418886661529541
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.7840317862580136e+19
# ti: 175.29215358931552
# time: 0.13825154304504395
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -4.763382711358166e+16
# ti: 176.29382303839733
# time: 0.11992192268371582
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5.435856794861432e+18
# ti: 177.29549248747912
# time: 0.1660785675048828
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -9.686220918283866e+20
# ti: 178.29716193656094
# time: 0.30038022994995117
# f(x_ini): 0.0
# iterracciones: 6
# res: 1
# norma de g_k 0.0
# f(x_k): -8.299729958857369e+21
# ti: 179.29883138564273
# time: 0.07186102867126465
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -6.416172941315522e+18
# ti: 180.30050083472455
# time: 0.2782135009765625
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -1.2539667464580918e+20
# ti: 181.30217028380633
# time: 0.23170685768127441
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -3.2888730465433793e+20
# ti: 182.30383973288815
# time: 0.19815444946289062
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.4878071571490994e+19
# ti: 183.30550918196994
# time: 0.21801209449768066
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -4.387646259787211e+21
# ti: 184.30717863105176
# time: 0.11204862594604492
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.167663231866897e+19
# ti: 185.30884808013354
# time: 0.12481403350830078
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.756931581975555e+18
# ti: 186.31051752921536
# time: 0.19199895858764648
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0479039617430262e+19
# ti: 187.31218697829715
# time: 0.31972599029541016
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -3.8312266799990104e+21
# ti: 188.31385642737897
# time: 0.12440609931945801
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -5.3899007754986206e+20
# ti: 189.31552587646075
# time: 0.2425673007965088
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -5.3682565482890075e+22
# ti: 190.31719532554257
# time: 0.1363811492919922
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.8283082896051149e+19
# ti: 191.31886477462436
# time: 0.14373469352722168
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.0502041628437376e+18
# ti: 192.32053422370618
# time: 0.13578510284423828
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -6.347621529308187e+20
# ti: 193.322203672788
# time: 0.18617486953735352
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -8.103373563117273e+20
# ti: 194.32387312186978
# time: 0.0838460922241211
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -6.325536865774647e+19
# ti: 195.3255425709516
# time: 0.07988595962524414
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.1089024334756514e+19
# ti: 196.3272120200334
# time: 0.21418142318725586
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -5.746358174907451e+19
# ti: 197.3288814691152
# time: 0.15073442459106445
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.2097767192789598e+20
# ti: 198.330550918197
# time: 0.1402127742767334
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.7625201992279253e+19
# ti: 199.3322203672788
# time: 0.23025822639465332
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -1.1823216501177016e+22
# ti: 200.3338898163606
# time: 0.3037245273590088
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -2.4848909369146973e+22
# ti: 201.3355592654424
# time: 0.07046341896057129
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -3.562146638412266e+17
# ti: 202.3372287145242
# time: 0.12480592727661133
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -7.233325615378378e+17
# ti: 203.33889816360602
# time: 0.10497522354125977
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5.45200209539891e+18
# ti: 204.3405676126878
# time: 0.07706904411315918
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -7.779532457511764e+18
# ti: 205.34223706176962
# time: 0.24689197540283203
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -9.521252291822071e+19
# ti: 206.3439065108514
# time: 0.2981417179107666
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -4.1232546458802234e+21
# ti: 207.34557595993323
# time: 0.03767752647399902
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -86255236032687.1
# ti: 208.34724540901502
# time: 0.12619471549987793
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0421213533812513e+20
# ti: 209.34891485809683
# time: 0.1406559944152832
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.467170998353599e+21
# ti: 210.35058430717862
# time: 0.31975221633911133
# f(x_ini): 0.0
# iterracciones: 6
# res: 1
# norma de g_k 0.0
# f(x_k): -1.5277869053297543e+22
# ti: 211.35225375626044
# time: 0.15980100631713867
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.1755424913283297e+19
# ti: 212.35392320534223
# time: 0.20064234733581543
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.1843334325078874e+17
# ti: 213.35559265442404
# time: 0.39411306381225586
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -1.4554908221453272e+21
# ti: 214.35726210350583
# time: 0.07981610298156738
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -8.380915056364438e+18
# ti: 215.35893155258765
# time: 0.08219051361083984
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.419071661659092e+18
# ti: 216.36060100166944
# time: 0.17840862274169922
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.2460401013543823e+20
# ti: 217.36227045075125
# time: 0.23332977294921875
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.6512532556281635e+19
# ti: 218.36393989983304
# time: 0.12631821632385254
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.8972573244645555e+18
# ti: 219.36560934891486
# time: 0.11163854598999023
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -6.460191003129567e+18
# ti: 220.36727879799665
# time: 0.13114094734191895
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.822675905625157e+19
# ti: 221.36894824707846
# time: 0.2373054027557373
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -5.150377650056925e+21
# ti: 222.37061769616025
# time: 0.19805216789245605
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.732838745710143e+19
# ti: 223.37228714524207
# time: 0.10701131820678711
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -7446114553309115.0
# ti: 224.3739565943239
# time: 0.19625544548034668
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -4.27893469731258e+18
# ti: 225.37562604340567
# time: 0.07864141464233398
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5.304826665955482e+18
# ti: 226.3772954924875
# time: 0.1776578426361084
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.836489275201664e+22
# ti: 227.37896494156928
# time: 0.23248624801635742
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -7.649654508400614e+20
# ti: 228.3806343906511
# time: 0.08595442771911621
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -8.260990064857362e+16
# ti: 229.38230383973288
# time: 0.11378788948059082
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5.318250848026388e+18
# ti: 230.3839732888147
# time: 0.16349124908447266
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -8.054463542738237e+21
# ti: 231.3856427378965
# time: 0.2088155746459961
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -4.927119053922039e+21
# ti: 232.3873121869783
# time: 0.17440271377563477
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.3083987189238589e+20
# ti: 233.3889816360601
# time: 0.18607497215270996
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -2.9780992089762456e+19
# ti: 234.3906510851419
# time: 0.1352388858795166
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.399451589887128e+18
# ti: 235.3923205342237
# time: 0.08006501197814941
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.3632753605276785e+18
# ti: 236.39398998330552
# time: 0.08532190322875977
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.2800144971772099e+19
# ti: 237.3956594323873
# time: 0.07483077049255371
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.135633127122611e+19
# ti: 238.39732888146912
# time: 0.17729926109313965
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -5.359546759929322e+18
# ti: 239.3989983305509
# time: 0.08223843574523926
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.058439856122996e+17
# ti: 240.40066777963273
# time: 0.0832681655883789
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.3239896219109718e+19
# ti: 241.40233722871452
# time: 0.07172489166259766
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5.507873215092406e+18
# ti: 242.40400667779633
# time: 0.1969313621520996
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -5.664306615264456e+21
# ti: 243.40567612687812
# time: 0.29798269271850586
# f(x_ini): 0.0
# iterracciones: 6
# res: 1
# norma de g_k 0.0
# f(x_k): -3.9882072033754323e+21
# ti: 244.40734557595994
# time: 0.16547584533691406
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.098978281312163e+17
# ti: 245.40901502504173
# time: 0.17421722412109375
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.384315358976402e+20
# ti: 246.41068447412354
# time: 0.23982858657836914
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -1.6774465389670517e+22
# ti: 247.41235392320533
# time: 0.13624954223632812
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.877977968787536e+20
# ti: 248.41402337228715
# time: 0.07712197303771973
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -7.75919069607675e+18
# ti: 249.41569282136894
# time: 0.08003997802734375
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.0819598113404163e+17
# ti: 250.41736227045075
# time: 0.18982195854187012
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -5.715466355303332e+18
# ti: 251.41903171953254
# time: 0.08178067207336426
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.4653828759736203e+19
# ti: 252.42070116861436
# time: 0.14169049263000488
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.9697089507648025e+21
# ti: 253.42237061769615
# time: 0.08330869674682617
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.2525090407171285e+19
# ti: 254.42404006677796
# time: 0.0764014720916748
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.8799338331992996e+18
# ti: 255.42570951585975
# time: 0.07711505889892578
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.9186993882135304e+18
# ti: 256.42737896494157
# time: 0.07984566688537598
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.9071739841815852e+18
# ti: 257.4290484140234
# time: 0.1808781623840332
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -4.182325364377206e+22
# ti: 258.4307178631052
# time: 0.17768120765686035
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -2.528309168963848e+20
# ti: 259.43238731218696
# time: 0.23398518562316895
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -2.0310932952099468e+21
# ti: 260.4340567612688
# time: 0.07635831832885742
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.803296358232974e+16
# ti: 261.4357262103506
# time: 0.12964224815368652
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -8.08279219509329e+19
# ti: 262.4373956594324
# time: 0.1820237636566162
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -2.0904305016053273e+22
# ti: 263.43906510851417
# time: 0.24794435501098633
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -3.101927747903754e+21
# ti: 264.440734557596
# time: 0.12375855445861816
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.029946258693157e+20
# ti: 265.4424040066778
# time: 0.0887918472290039
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.9037276202034173e+18
# ti: 266.4440734557596
# time: 0.17778372764587402
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.122036497459747e+19
# ti: 267.4457429048414
# time: 0.08004522323608398
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -9.12175669446388e+18
# ti: 268.4474123539232
# time: 0.130265474319458
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.8790405523605304e+20
# ti: 269.449081803005
# time: 0.18169021606445312
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.063437352625192e+20
# ti: 270.45075125208683
# time: 0.22390365600585938
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -2.02251397270908e+20
# ti: 271.4524207011686
# time: 0.23828959465026855
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -5.45361526208383e+18
# ti: 272.4540901502504
# time: 0.09270334243774414
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.8211902713169654e+18
# ti: 273.4557595993322
# time: 0.17229557037353516
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.7645573854529507e+20
# ti: 274.45742904841404
# time: 0.2146601676940918
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -3.1209972184356183e+21
# ti: 275.4590984974958
# time: 0.09541654586791992
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.6908462493631606e+18
# ti: 276.4607679465776
# time: 0.057885169982910156
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -138465848045554.1
# ti: 277.46243739565944
# time: 0.21684622764587402
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -2.5117577684829015e+21
# ti: 278.46410684474125
# time: 0.2420661449432373
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.536641360982318e+20
# ti: 279.465776293823
# time: 0.14942026138305664
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.1408458816671777e+19
# ti: 280.46744574290483
# time: 0.4501218795776367
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -6.247153026872545e+21
# ti: 281.46911519198665
# time: 0.16060757637023926
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.2882649198569906e+19
# ti: 282.47078464106846
# time: 0.09952592849731445
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -8.78353276929756e+17
# ti: 283.4724540901502
# time: 0.17136716842651367
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.843902377963323e+19
# ti: 284.47412353923204
# time: 0.0968008041381836
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -4.163309347590361e+18
# ti: 285.47579298831386
# time: 0.16373062133789062
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.7957038635554803e+20
# ti: 286.4774624373957
# time: 0.10170459747314453
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.5726678011683638e+18
# ti: 287.47913188647743
# time: 0.18265724182128906
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.6519871249476475e+18
# ti: 288.48080133555925
# time: 0.16484689712524414
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.5149417818528824e+18
# ti: 289.48247078464107
# time: 0.5851399898529053
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -2.432396478979971e+21
# ti: 290.4841402337229
# time: 341.8732645511627
# f(x_ini): 0.0
# iterracciones: 9999
# res: 0
# norma de g_k nan
# f(x_k): nan
# ti: 291.4858096828047
# time: 0.18949604034423828
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.982598462197512e+21
# ti: 292.48747913188646
# time: 0.0898594856262207
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0371797673120472e+16
# ti: 293.4891485809683
# time: 0.1459503173828125
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.2642496135078918e+19
# ti: 294.4908180300501
# time: 0.15308785438537598
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.029976092572069e+22
# ti: 295.4924874791319
# time: 0.1815505027770996
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.866550142814833e+19
# ti: 296.49415692821367
# time: 0.13141179084777832
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -3.562223581188839e+20
# ti: 297.4958263772955
# time: 0.07712054252624512
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -4.897861357082652e+16
# ti: 298.4974958263773
# time: 0.16136693954467773
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.626755963119319e+18
# ti: 299.4991652754591
# time: 0.1507861614227295
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.120254632903278e+21
# ti: 300.5008347245409
# time: 0.11759543418884277
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -9.622683958951582e+18
# ti: 301.5025041736227
# time: 0.08342790603637695
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -3.757266149099912e+19
# ti: 302.5041736227045
# time: 0.07788324356079102
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.7910689229038358e+17
# ti: 303.50584307178633
# time: 0.08379197120666504
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -9.930664392882853e+16
# ti: 304.5075125208681
# time: 0.15421295166015625
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.5807941637575626e+20
# ti: 305.5091819699499
# time: 0.1378004550933838
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.447788731063431e+20
# ti: 306.5108514190317
# time: 0.07971477508544922
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.1813826354244426e+19
# ti: 307.51252086811354
# time: 0.08831787109375
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -7.748160762184669e+18
# ti: 308.5141903171953
# time: 0.159759521484375
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0283495132647864e+19
# ti: 309.5158597662771
# time: 0.18886804580688477
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -7.566836824066047e+20
# ti: 310.51752921535893
# time: 0.19292521476745605
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.028249126751512e+21
# ti: 311.51919866444075
# time: 0.07993435859680176
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -6.728860164842421e+18
# ti: 312.5208681135225
# time: 0.1771848201751709
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.1715371395514816e+21
# ti: 313.5225375626043
# time: 0.08977460861206055
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.8480978339091816e+16
# ti: 314.52420701168614
# time: 0.17982006072998047
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -8.909377707147506e+20
# ti: 315.52587646076796
# time: 0.14990663528442383
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -9.539318031124711e+19
# ti: 316.5275459098497
# time: 0.14510440826416016
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -7.951698188546505e+19
# ti: 317.52921535893154
# time: 0.25556039810180664
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -2.900842537350991e+21
# ti: 318.53088480801335
# time: 0.13384366035461426
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -6.51072693354057e+18
# ti: 319.53255425709517
# time: 0.14874577522277832
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -9.931856197195045e+18
# ti: 320.53422370617693
# time: 0.13228058815002441
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.990945974697501e+20
# ti: 321.53589315525875
# time: 0.10011434555053711
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -3.5617748588701036e+18
# ti: 322.53756260434056
# time: 0.24766135215759277
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.2688961848462134e+21
# ti: 323.5392320534224
# time: 0.10700678825378418
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.2203048434508224e+18
# ti: 324.5409015025042
# time: 0.2221205234527588
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.6953432926115855e+18
# ti: 325.54257095158596
# time: 0.6460225582122803
# f(x_ini): 0.0
# iterracciones: 6
# res: 1
# norma de g_k 0.0
# f(x_k): -1.1361409146064952e+22
# ti: 326.5442404006678
# time: 410.80397605895996
# f(x_ini): 0.0
# iterracciones: 9999
# res: 0
# norma de g_k nan
# f(x_k): nan
# ti: 327.5459098497496
# time: 0.08489537239074707
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -3.916570988497815e+19
# ti: 328.5475792988314
# time: 0.18414974212646484
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -6.306309429219873e+21
# ti: 329.54924874791317
# time: 0.08368682861328125
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5053106555528237.0
# ti: 330.550918196995
# time: 0.12610936164855957
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -6.280175820837021e+19
# ti: 331.5525876460768
# time: 0.23122835159301758
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -3.535513257837104e+22
# ti: 332.5542570951586
# time: 0.08494853973388672
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.4349654541099884e+18
# ti: 333.5559265442404
# time: 0.12962698936462402
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.7365642322662123e+20
# ti: 334.5575959933222
# time: 0.13029885292053223
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -7.315876691473081e+18
# ti: 335.559265442404
# time: 0.12978124618530273
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.7374926334546657e+19
# ti: 336.56093489148583
# time: 0.07842707633972168
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.1035816330929582e+19
# ti: 337.5626043405676
# time: 0.14150667190551758
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.1406351469765476e+21
# ti: 338.5642737896494
# time: 0.17191815376281738
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -2.29048945026592e+21
# ti: 339.5659432387312
# time: 0.15237116813659668
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.5409542751809892e+19
# ti: 340.56761268781304
# time: 0.13164734840393066
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.253063809801502e+18
# ti: 341.5692821368948
# time: 0.09050583839416504
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5.466822900617251e+18
# ti: 342.5709515859766
# time: 0.1393425464630127
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.903923925435062e+19
# ti: 343.57262103505843
# time: 0.13436222076416016
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.322080592714013e+20
# ti: 344.57429048414025
# time: 0.08299589157104492
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -4.946888532891877e+18
# ti: 345.575959933222
# time: 0.12323427200317383
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1848679263192925.5
# ti: 346.5776293823038
# time: 0.17647647857666016
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -9.613338152523899e+20
# ti: 347.57929883138564
# time: 0.13261651992797852
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.347490451442074e+20
# ti: 348.58096828046746
# time: 0.08440399169921875
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5.543793997963748e+18
# ti: 349.5826377295492
# time: 0.08107399940490723
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -4.163846030152892e+18
# ti: 350.58430717863104
# time: 0.19203972816467285
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -6.383303473399388e+18
# ti: 351.58597662771285
# time: 0.13296127319335938
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.6623728582658912e+19
# ti: 352.58764607679467
# time: 0.08552742004394531
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.3488439295938894e+19
# ti: 353.5893155258765
# time: 0.08409762382507324
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0045462976783364e+19
# ti: 354.59098497495825
# time: 0.0803840160369873
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -7.459140599852246e+18
# ti: 355.59265442404006
# time: 0.12671184539794922
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -6.441412538150679e+18
# ti: 356.5943238731219
# time: 0.13312697410583496
# ...
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.496771406588079e+20
# ti: 481.80300500834727
# time: 0.1804196834564209
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.3715151661922402e+22
# ti: 482.80467445742903
# time: 0.07960867881774902
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.7126785593728243e+18
# ti: 483.80634390651085
# time: 0.14006257057189941
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1689944892868203.0
# ti: 484.80801335559266
# time: 0.23245525360107422
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.8869478098085474e+19
# ti: 485.8096828046745
# time: 0.277695894241333
# f(x_ini): 0.0
# iterracciones: 6
# res: 1
# norma de g_k 0.0
# f(x_k): -2.8530722091269803e+21
# ti: 486.81135225375624
# time: 0.1832418441772461
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.436035480834189e+21
# ti: 487.81302170283806
# time: 0.15524530410766602
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.3896205663690565e+20
# ti: 488.8146911519199
# time: 0.17170429229736328
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -7.668331757430536e+18
# ti: 489.8163606010017
# time: 0.1999523639678955
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -8.645586911404969e+19
# ti: 490.81803005008345
# time: 0.12424445152282715
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.886864697311909e+19
# ti: 491.81969949916527
# time: 0.13562631607055664
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0007805469722306e+21
# ti: 492.8213689482471
# time: 0.0741581916809082
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -3.58451540686433e+18
# ti: 493.8230383973289
# time: 0.20936250686645508
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -3.77831064237316e+19
# ti: 494.82470784641066
# time: 0.13201165199279785
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -7.741830461947561e+17
# ti: 495.8263772954925
# time: 0.09807658195495605
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -4.2405725352396467e+18
# ti: 496.8280467445743
# time: 0.24184155464172363
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -2.510739930977383e+21
# ti: 497.8297161936561
# time: 0.3139486312866211
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -2.6437898817652667e+22
# ti: 498.83138564273787
# time: 0.13320446014404297
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.6549411544157985e+20
# ti: 499.8330550918197
# time: 0.12927556037902832
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -9.01514642136499e+16
# ti: 500.8347245409015
# time: 0.17975664138793945
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.3479929752694014e+20
# ti: 501.8363939899833
# time: 0.08251738548278809
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -7.435561775927229e+19
# ti: 502.8380634390651
# time: 0.14632081985473633
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.8787670729017105e+20
# ti: 503.8397328881469
# time: 0.16800618171691895
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.5550416891013045e+20
# ti: 504.8414023372287
# time: 0.18407630920410156
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.122427244219659e+18
# ti: 505.84307178631053
# time: 0.22860288619995117
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.6198613947771214e+20
# ti: 506.8447412353923
# time: 0.08007526397705078
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -4.731752894437476e+19
# ti: 507.8464106844741
# time: 0.12784314155578613
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5.285989272625474e+18
# ti: 508.8480801335559
# time: 0.20000553131103516
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.8596567898137326e+19
# ti: 509.84974958263774
# time: 0.26528406143188477
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.5432050226705242e+18
# ti: 510.8514190317195
# time: 0.11457395553588867
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.2051105585526914e+17
# ti: 511.8530884808013
# time: 0.4976472854614258
# f(x_ini): 0.0
# iterracciones: 7
# res: 1
# norma de g_k 0.0
# f(x_k): -2.265389601901674e+22
# ti: 512.8547579298831
# time: 0.5526154041290283
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -1.8953065581655095e+21
# ti: 513.8564273789649
# time: 0.5095365047454834
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -8.978863376871047e+19
# ti: 514.8580968280468
# time: 0.312985897064209
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.4186009779857646e+19
# ti: 515.8597662771285
# time: 0.10262632369995117
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -4.201222774126859e+16
# ti: 516.8614357262104
# time: 0.16818594932556152
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.375676444576897e+19
# ti: 517.8631051752922
# time: 0.43205809593200684
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.9295731410182367e+21
# ti: 518.8647746243739
# time: 0.5271780490875244
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -4.814740524956244e+21
# ti: 519.8664440734558
# time: 0.42150235176086426
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -2.028607889022383e+20
# ti: 520.8681135225376
# time: 0.27365970611572266
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5.224610768370475e+16
# ti: 521.8697829716193
# time: 0.4243133068084717
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -7.023819545320216e+17
# ti: 522.8714524207012
# time: 0.6784071922302246
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -5.8805106821428265e+19
# ti: 523.873121869783
# time: 0.32383275032043457
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.173661565578885e+19
# ti: 524.8747913188648
# time: 0.24730849266052246
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.396150897663808e+19
# ti: 525.8764607679466
# time: 1.230546474456787
# f(x_ini): 0.0
# iterracciones: 6
# res: 1
# norma de g_k 0.0
# f(x_k): -1.2804053637940034e+19
# ti: 526.8781302170283
# time: 0.9795818328857422
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -2.143994393997764e+20
# ti: 527.8797996661102
# time: 0.5613925457000732
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -7.623757262533444e+19
# ti: 528.881469115192
# time: 0.32889890670776367
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -7.564680234366886e+19
# ti: 529.8831385642737
# time: 0.29770374298095703
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -7.178483816665524e+19
# ti: 530.8848080133556
# time: 0.2998018264770508
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.5140450494199414e+18
# ti: 531.8864774624374
# time: 0.7646594047546387
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -6.898438700541218e+18
# ti: 532.8881469115192
# time: 0.3002188205718994
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -8.928716724337875e+18
# ti: 533.889816360601
# time: 0.4911658763885498
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -9.582058391329496e+20
# ti: 534.8914858096828
# time: 0.7073571681976318
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -2.3988667775475584e+21
# ti: 535.8931552587646
# time: 0.3302304744720459
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5.822723878294223e+18
# ti: 536.8948247078464
# time: 0.6296870708465576
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.3287298675934026e+17
# ti: 537.8964941569282
# time: 0.2705235481262207
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.742969442062931e+18
# ti: 538.89816360601
# time: 0.4367635250091553
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -8.001253377787513e+20
# ti: 539.8998330550918
# time: 0.26351213455200195
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.2140662626215516e+19
# ti: 540.9015025041737
# time: 0.3083982467651367
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5.938973082799164e+18
# ti: 541.9031719532554
# time: 0.47167301177978516
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.8346195738401705e+18
# ti: 542.9048414023372
# time: 0.7705285549163818
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0085326087869563e+20
# ti: 543.9065108514191
# time: 0.7481529712677002
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -1.1771842818874945e+22
# ti: 544.9081803005008
# time: 0.26706385612487793
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -9.37350528610364e+19
# ti: 545.9098497495827
# time: 0.4545936584472656
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -5.08278353676308e+20
# ti: 546.9115191986645
# time: 0.43007874488830566
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.8845650836893217e+19
# ti: 547.9131886477462
# time: 0.24645709991455078
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.462964778702649e+18
# ti: 548.9148580968281
# time: 0.27694082260131836
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -4.671529401386243e+18
# ti: 549.9165275459098
# time: 0.4290351867675781
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -9.47449200868126e+19
# ti: 550.9181969949916
# time: 0.7690677642822266
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -9.462296926634912e+21
# ti: 551.9198664440735
# time: 0.4398465156555176
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.686108247178476e+19
# ti: 552.9215358931552
# time: 0.1896967887878418
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -228035568413618.88
# ti: 553.9232053422371
# time: 0.3415396213531494
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.8254115951328566e+18
# ti: 554.9248747913189
# time: 0.2780280113220215
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.759252171170823e+18
# ti: 555.9265442404006
# time: 0.5282802581787109
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -4.314168782807838e+19
# ti: 556.9282136894825
# time: 0.27160072326660156
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.3635520169231413e+19
# ti: 557.9298831385643
# time: 0.2713160514831543
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.731032591578607e+18
# ti: 558.931552587646
# time: 0.6449940204620361
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -8.46766160342655e+19
# ti: 559.9332220367279
# time: 0.423020601272583
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -7.949077871020738e+21
# ti: 560.9348914858097
# time: 0.2747917175292969
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.947074255367061e+20
# ti: 561.9365609348915
# time: 0.5777857303619385
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -6.71716544746024e+21
# ti: 562.9382303839733
# time: 0.6495251655578613
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -2.3501699729657135e+19
# ti: 563.939899833055
# time: 0.4680349826812744
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -7.874659622859688e+17
# ti: 564.9415692821369
# time: 0.47981929779052734
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5.759933880813471e+18
# ti: 565.9432387312187
# time: 0.42655491828918457
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -8.637951698220415e+18
# ti: 566.9449081803004
# time: 0.9639840126037598
# f(x_ini): 0.0
# iterracciones: 5
# res: 1
# norma de g_k 0.0
# f(x_k): -3.424363213425074e+20
# ti: 567.9465776293823
# time: 0.3800044059753418
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5.592935557268932e+18
# ti: 568.9482470784641
# time: 0.452394962310791
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -6.501425478246337e+17
# ti: 569.949916527546
# time: 0.5501649379730225
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0219939514415428e+20
# ti: 570.9515859766277
# time: 0.5197179317474365
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.710006738419953e+22
# ti: 571.9532554257095
# time: 0.5268199443817139
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -9.253225595647758e+19
# ti: 572.9549248747913
# time: 0.5056643486022949
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.615551342594023e+20
# ti: 573.9565943238731
# time: 0.22976970672607422
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.3877137485893937e+18
# ti: 574.9582637729549
# time: 0.1357743740081787
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -6.223529391032778e+20
# ti: 575.9599332220367
# time: 0.08220934867858887
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.9320275017867244e+19
# ti: 576.9616026711185
# time: 0.07983589172363281
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.2147267157499355e+19
# ti: 577.9632721202004
# time: 0.10766959190368652
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.5107696935114696e+18
# ti: 578.9649415692821
# time: 0.1442880630493164
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.6653266082074355e+18
# ti: 579.9666110183639
# time: 0.1739189624786377
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -3.644545057471967e+20
# ti: 580.9682804674458
# time: 0.12025094032287598
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -3.326436618743491e+20
# ti: 581.9699499165275
# time: 0.07601475715637207
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.0924534819544275e+19
# ti: 582.9716193656094
# time: 0.08127832412719727
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -3.364297528031205e+19
# ti: 583.9732888146912
# time: 0.0723731517791748
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.2985887400912091e+19
# ti: 584.9749582637729
# time: 0.1404869556427002
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -5.351745699175065e+17
# ti: 585.9766277128548
# time: 0.1425189971923828
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.1014300311206093e+19
# ti: 586.9782971619366
# time: 0.11787080764770508
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -6.897418194264482e+19
# ti: 587.9799666110183
# time: 0.196028470993042
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -1.663066719954298e+20
# ti: 588.9816360601002
# time: 0.0821232795715332
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -4.748487118343137e+18
# ti: 589.983305509182
# time: 0.13669180870056152
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -2.4232233913623567e+18
# ti: 590.9849749582638
# time: 0.08186960220336914
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -4.546470394120198e+19
# ti: 591.9866444073456
# time: 0.11841201782226562
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.1968919435251781e+21
# ti: 592.9883138564273
# time: 0.13999724388122559
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.5858212265176846e+21
# ti: 593.9899833055092
# time: 0.08003044128417969
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -5.779939297804659e+18
# ti: 594.991652754591
# time: 0.07809281349182129
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -1.7299945084902944e+17
# ti: 595.9933222036727
# time: 0.17106008529663086
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.1897456578054832e+17
# ti: 596.9949916527546
# time: 0.29020023345947266
# f(x_ini): 0.0
# iterracciones: 4
# res: 1
# norma de g_k 0.0
# f(x_k): -7.573247573503671e+21
# ti: 597.9966611018364
# time: 0.2087724208831787
# f(x_ini): 0.0
# iterracciones: 2
# res: 1
# norma de g_k 0.0
# f(x_k): -2.8110729550954375e+20
# ti: 598.9983305509182
# time: 0.1600348949432373
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.7499402155044032e+21
# ti: 600.0
# time: 0.16398310661315918
# f(x_ini): 0.0
# iterracciones: 3
# res: 1
# norma de g_k 0.0
# f(x_k): -1.768523909819187e+19
